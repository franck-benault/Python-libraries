# %% [markdown]
# # Sympy example
# ## symbolic mathematics

# %%
from sympy import *

x=symbols('x')
f=1/x
print(limit(f,x,oo))

# %%
x=symbols('x')
f=(1+1/x)**x
print(limit(f,x,oo))
print(limit(f,x,oo).evalf())
